# %% [markdown]
# # Korelacje

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr

# %%
d = {
    'x': np.random.normal(100, 15, 1000),
    'y1': np.random.normal(100, 15, 1000)
}

df = pd.DataFrame(d)

# correlated stuff
df['y2'] = (df.x * .4) + (df.y1 * .6)
df['y3'] = -(df.x * .2) + (df.y1 * .8)
df['y4'] = -(df.x * .5) + (df.y1 * .5)

# %%
df
# Out:
#               x          y1          y2         y3         y4
# 0     98.365274  104.993107  102.341974  64.321431   3.313917
# 1    104.739097  108.170880  106.798167  65.588884   1.715891
# 2    103.473697  127.056947  117.623647  80.950818  11.791625
# 3    117.202694  124.869452  121.802749  76.455023   3.833379
# 4    118.527101  118.488023  118.503654  71.084999  -0.019539
# ..          ...         ...         ...        ...        ...
# 995  120.200814  111.175357  114.785540  64.900122  -4.512729
# 996  102.710220  107.888455  105.817161  65.768720   2.589117
# 997   92.330504   69.943648   78.898390  37.488818 -11.193428
# 998  117.216253  109.317647  112.477090  64.010867  -3.949303
# 999   99.186289  105.606052  103.038147  64.647584   3.209881
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## v1

# %%
sns.relplot(x='x', y='y1', data=df)

# %%
r, p = pearsonr(df.x, df.y1)
print(f"r = {round(r, 2)}; p = {round(p, 3)}")
# Out:
# r = -0.03; p = 0.331

# %% [markdown]
# ## v2

# %%
sns.relplot(x='x', y='y2', data=df)

# %%
r, p = pearsonr(df.x, df.y2)
print(f"r = {round(r, 2)}; p = {round(p, 3)}")
# Out:
# r = 0.54; p = 0.0

# %% [markdown]
# ## v3

# %%
sns.relplot(x='x', y='y3', data=df)

# %%
r, p = pearsonr(df.x, df.y3)
print(f"r = {round(r, 2)}; p = {round(p, 3)}")
# Out:
# r = -0.27; p = 0.0

# %% [markdown]
# ## v4

# %%
sns.relplot(x='x', y='y4', data=df)

# %%
r, p = pearsonr(df.x, df.y4)
print(f"r = {round(r, 2)}; p = {round(p, 3)}")
# Out:
# r = -0.72; p = 0.0
